# %%
import pandas as pd
df=pd.read_csv('zomato.csv')

# %%
df_=df[['name','cuisines']].copy()

# %%
df_
# Out:
#                                                     name  \
# 0                                                  Jalsa
# 1                                         Spice Elephant
# 2                                        San Churro Cafe
# 3                                  Addhuri Udupi Bhojana
# 4                                          Grand Village
# ...                                                  ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...
# 51713                           Vinod Bar And Restaurant
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 51716                       The Nest - The Den Bengaluru
#
#                                      cuisines
# 0              North Indian, Mughlai, Chinese
# 1                 Chinese, North Indian, Thai
# 2                      Cafe, Mexican, Italian
# 3                  South Indian, North Indian
# ...

# %%
df_['cuisines'] = df_['cuisines'].str.split(',')
df_ = df_.explode('cuisines', ignore_index=True)

# %%
df_
# Out:
#                                                      name       cuisines
# 0                                                   Jalsa   North Indian
# 1                                                   Jalsa        Mughlai
# 2                                                   Jalsa        Chinese
# 3                                          Spice Elephant        Chinese
# 4                                          Spice Elephant   North Indian
# ...                                                   ...            ...
# 126859  Plunge - Sheraton Grand Bengaluru Whitefield H...    Finger Food
# 126860  Chime - Sheraton Grand Bengaluru Whitefield Ho...    Finger Food
# 126861                       The Nest - The Den Bengaluru    Finger Food
# 126862                       The Nest - The Den Bengaluru   North Indian
# 126863                       The Nest - The Den Bengaluru    Continental
#
# [126864 rows x 2 columns]

# %%
df_.to_csv('cuisines.csv', index=False)
